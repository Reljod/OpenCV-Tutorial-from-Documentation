# %%
import numpy as np
import cv2 as cv

# %%
img = cv.imread("dahyun.jpg")

# %%
cv.imshow("Dahyun", img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
px = img[0:600, 0:600]

# %%
img.size
# Out:
# 2764800

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
eye = img[240:300, 470:585]

# %%
img[170:230, 600:715] = eye

# %%
cv.imshow("Dahyun", img)
cv.imshow("Eye", eye)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
cv.imwrite("DahyunThirdEye.jpg", img)
# Out:
# True

# %%
b = img[:,:,0]
g = img[:,:,1]
r = img[:,:,2]

# %%
cv.imshow("Dahyun", ax)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
ax = np.dstack((r,g,b))

# %%
cv.imwrite("DahyunBlue.jpg", ax)
# Out:
# True

# %%
ax.shape
# Out:
# (960, 960, 3)

# %%
img.shape
# Out:
# (960, 960, 3)

# %%
from matplotlib import pyplot as plt
BLUE = [255,0,0]
img1 = cv.imread('dahyun.jpg')
replicate = cv.copyMakeBorder(img1,10,10,10,10,cv.BORDER_REPLICATE)
reflect = cv.copyMakeBorder(img1,10,10,10,10,cv.BORDER_REFLECT)
reflect101 = cv.copyMakeBorder(img1,10,10,10,10,cv.BORDER_REFLECT_101)
wrap = cv.copyMakeBorder(img1,10,10,10,10,cv.BORDER_WRAP)
constant= cv.copyMakeBorder(img1,10,10,10,10,cv.BORDER_CONSTANT,value=BLUE)
plt.subplot(231),plt.imshow(img1,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-23443a866e93> in <module>
#      13 plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
#      14 plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')
# ---> 15 plt.fig_size((20,20))
#      16 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'fig_size'
